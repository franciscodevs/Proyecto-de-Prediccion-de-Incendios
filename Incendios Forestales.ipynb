# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import pandas_profiling

# %% [markdown]
# # Data Visualization

# %%
df = pd.read_csv("dataset_galicia.csv")

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#            id  superficie       fecha        lat       lng idprovincia  \
# 0  2001150021         5.0  2001-02-20  43.703581 -8.038777    A Coruña
# 1  2001150094         1.5  2001-02-25  43.186836 -8.685470    A Coruña
# 2  2001150145         1.5  2001-04-13  43.699889 -7.984566    A Coruña
# 3  2001150151         1.1  2001-04-13  42.758649 -8.917814    A Coruña
# 4  2001150153         1.5  2001-04-13  43.063218 -9.235604    A Coruña
#
#   idmunicipio              causa  muertos  heridos  ...  TMIN  TMAX  VELMEDIA  \
# 0     CEDEIRA        negligencia        0        0  ...   7.0  15.6   2-4 m/s
# 1    CARBALLO       intencionado        0        0  ...   6.5  11.6   4-6 m/s
# 2     CEDEIRA        negligencia        0        0  ...  10.4  17.4   4-6 m/s
# 3     LOUSAME  causa desconocida        0        0  ...  10.4  17.4   4-6 m/s
# 4    MUXÃÂA       intencionado        0        0  ...  10.4  17.4   4-6 m/s
#
#    RACHA   SOL Trimestre      Mes   Año  DIR_VIENTO  PRES_RANGE
# ...

# %%
df.shape
# Out:
# (12976, 12)

# %%
df.dtypes
# Out:
# superficie    float64
# lat           float64
# lng           float64
# time_ctrl     float64
# personal        int64
# medios          int64
# TMEDIA        float64
# RACHA         float64
# SOL           float64
# Año             int64
# PRES_RANGE    float64
# target          int64
# dtype: object

# %%
df.describe()
# Out:
#                  id    superficie           lat           lng       muertos  \
# count  1.297600e+04  12976.000000  12976.000000  12976.000000  12976.000000
# mean   2.005867e+09      2.586703     42.555421     -7.994614      0.000077
# std    3.830998e+06      1.863610      0.451212      0.562395      0.008779
# min    2.001150e+09      1.000000     41.833819     -9.293500      0.000000
# 25%    2.003150e+09      1.250000     42.189372     -8.422458      0.000000
# 50%    2.005151e+09      2.000000     42.470163     -7.987553      0.000000
# 75%    2.009150e+09      3.000000     42.932203     -7.556844      0.000000
# max    2.015361e+09     10.200000     43.730713     -6.771548      1.000000
#
#             heridos     time_ctrl      time_ext      personal        medios  \
# count  12976.000000  12976.000000  12976.000000  12976.000000  12976.000000
# mean       0.000462      1.781149      1.781149     12.281520      1.964396
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
profile = pandas_profiling.ProfileReport(df)
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# # Data Wrangling
